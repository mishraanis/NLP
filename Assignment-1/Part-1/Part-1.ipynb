# %%
import collections, re

class Tokenizer:
    def __init__(self):
        self.vocab = {}
        self.merges = collections.defaultdict(int)
        self.tokens = []

# %% [markdown]
# Learn Vocabulary

# %%
def learn_vocabulary(self, corpus, num_merges):
    # Count character frequencies in the corpus
    word_freqs = collections.defaultdict(int)
    for word in corpus:
        # print("word: ", word)
        _word = ' '.join(list(word)) + ' </w>'
        # print("_word: ", _word)
        word_freqs[_word] += 1

    # Create the initial vocabulary
    for word, freq in word_freqs.items():
        self.vocab[word] = freq

    print("self.vocab", self.vocab)
    for word in self.vocab:
        self.tokens.extend(word.split())
    # Learn the split rules and frequencies
    for _ in range(num_merges):
        pairs = collections.defaultdict(int)
        for word, freq in self.vocab.items():
            symbols = word.split()
            # print("symbols: ", symbols)
            for i in range(len(symbols) - 1):
                pairs[symbols[i], symbols[i + 1]] += freq

        # print("pairs: ", pairs)
        if not pairs:
            break

        # Get the most frequent pair
        most_frequent_pair = max(pairs, key=pairs.get)
        # print("most_frequent_pair: ", most_frequent_pair)
        self.merges[most_frequent_pair] += 1
        # print("self.merges: ", self.merges)
        # Merge the most frequent pair in the vocabulary
        new_vocab = {}
        bigram = re.escape(' '.join(most_frequent_pair)) 
        p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)') 
        for word in self.vocab:
            # new_vocab[word] = self.vocab[word]
            new_word = p.sub(''.join(most_frequent_pair), word)
            new_vocab[new_word] = self.vocab[word]
        self.vocab = new_vocab
        
        # traverse the vocab and add the new words to mastervocab
        for word in self.vocab:
            self.tokens.extend(word.split())

# %% [markdown]
# Tokenize

# %%
def _apply_merge_rules(self, sentence):
    for merge in self.merges:
        sentence = sentence.replace(' '.join(merge), ''.join(merge))
    return sentence

def _split_word(self, word):
    if len(word) == 1:
        return [word]

    split_tokens = []
    for i in range(len(word) - 1):
        pair = (word[i], word[i+1])
        if pair in self.merges:
            split_tokens.append(''.join(pair))
        else:
            split_tokens.append(word[i])
    split_tokens.append(word[-1])
    return split_tokens

def tokenize(self, sentence):
    tokens = []
    sentence = list('$'.join(list(sentence.split())))
    sentence.append('$')
    for i in range(len(sentence)):
        if(sentence[i] == '$'):
            sentence[i] = '</w>'

    print("sentence: ", sentence)
    sentence = '_'+'_,_'.join(sentence) + '_'
    print("sentence: ", sentence)
    for merge_rules in self.merges:
        print("merge_rules: ", merge_rules)
        rule1 = '_'+'_,_'.join(merge_rules)+'_'
        rule2 = '_'+(''.join(merge_rules))+ '_'
        print("rule1:", rule1, ", rule2: ", rule2)
        sentence = sentence.replace(rule1, rule2)
        print("sentence: ", sentence)
    return sentence.replace('_', '').replace('</w>', '$')

# %%
Tokenizer.learn_vocabulary = learn_vocabulary
Tokenizer.tokenize = tokenize
Tokenizer._apply_merge_rules = _apply_merge_rules

# %%
corpus = []
with open('../../Assignment-1/Dataset/corpus.txt', 'r') as f:
    for line in f:
        # print("line.strip()", line.strip())
        corpus.extend(line.strip().split())

tokenizer = Tokenizer()
tokenizer.learn_vocabulary(corpus, 1000)
# Out:
# self.vocab {'i </w>': 3789, 's t a n d </w>': 10, 'h e r e </w>': 37, 'f e e l </w>': 1637, 'e m p t y </w>': 9, 'a </w>': 916, 'c l a s s </w>': 13, 'p o s t </w>': 14, 'c o u n t </w>': 4, 'l i n k </w>': 2, 'h r e f </w>': 25, 'h t t p </w>': 30, 'm o o s h i l u </w>': 1, 'l i t e r a l l y </w>': 4, 'j u s t </w>': 226, 't e x t </w>': 3, 't y c h e l l e </w>': 1, 't o </w>': 1340, 's e e </w>': 45, 'i f </w>': 134, 's h e </w>': 72, 'w a n t s </w>': 7, 'h a n g </w>': 1, 'o u t </w>': 113, 'b e c a u s e </w>': 183, 'r e a d i n g </w>': 13, 'w h a t </w>': 125, 'w r o t e </w>': 4, 'a b o u t </w>': 298, 'm y </w>': 642, 'n o n e x i s t e n t </w>': 1, 's o c i a l </w>': 7, 'l i f e </w>': 96, 'm a d e </w>': 36, 'm e </w>': 382, 's o </w>': 366, 'p a t h e t i c </w>': 6, 'r e a l l y </w>': 157, 'r e g r e t f u l </w>': 6, 'w h e n </w>': 228, 'h e a r i n g </w>': 4, 't h a t </w>': 796, 's h i n a e </w>': 2, 'g o t </w>': 41, 'm a r r i e d </w>': 4, 'a n o t h e r </w>': 19, 'm a n </w>': 13, 'o h </w>': 8, 'i t </w>': 515, 's </w>': 82, 's a d </w>': 24, 'h o p e </w>': 20, 'a l e x </w>': 1, 'a n d </w>': 1453, 'c a n </w>': 136, 'b e </w>': 275, 'c o u p l e </w>': 13, 'i n </w>': 509, 'r e a l </w>': 13, 't h e y </w>': 109, 'r e </w>': 21, 'p e r f e c t </w>': 9, 'f o r </w>': 387, 'e a c h </w>': 17, 'o t h e r </w>': 47, 'b e l i e v e d </w>': 2, 'w a s </w>': 339, 't r u e </w>': 8, 'l o v e </w>': 70, 'd e v a s t a t e d </w>': 8, 'w a n t e d </w>': 20, 's e t t l e </w>': 3, 'd o w n </w>': 31, 'h a v e </w>': 302, 't h e </w>': 1277, 'w h o l e </w>': 14, 'm a r r i a g e </w>': 1, 'k i d s </w>': 16, 't h i n g </w>': 23, 'w i t h </w>': 307, 'h i m </w>': 84, 'u n i m p o r t a n t </w>': 4, 'i n a d e q u a t e </w>': 10, 'v e r y </w>': 125, 'l o w </w>': 10, 'a l r e a d y </w>': 28, 'h o r r i b l e </w>': 7, 'a g a i n </w>': 54, 'p e r s o n i f y i n g </w>': 1, 'a n </w>': 72, 'a c t </w>': 4, 'w e r e </w>': 47, 'n o t </w>': 279, 'c a u s e </w>': 13, 'o f </w>': 751, 't h e i r </w>': 57, 'p r o g e n y </w>': 1, 'w h o </w>': 87, 's h o u l d </w>': 50, 'g e n u f l e c t i n g </w>': 1, 'a t </w>': 240, 'h e r </w>': 97, 'w r o n g e d </w>': 9, 'w o m a n </w>': 12, 'f e e t </w>': 5, 'i l l </w>': 23, 'p a r a p h r a s e </w>': 1, 'r a n t e d </w>': 1, 'b e i n g </w>': 86, 'a b l e </w>': 18, 't r u s t </w>': 11, 'a n y b o d y </w>': 4, 'h u r t </w>': 11, 'f e e l i n g </w>': 794, 'r e j e c t e d </w>': 8, 'e t c </w>': 8, 'a c h i n g </w>': 6, 'a l l </w>': 179, 't i m e s </w>': 28, 'd a y </w>': 60, 'd u m b </w>': 6, 'f i r s t </w>': 27, 'r u n </w>': 8, 't h r o u g h </w>': 41, 's e e m s </w>': 17, 'o v e r </w>': 62, 'h e a d </w>': 16, 'a m p </w>': 8, 'l i t t l e </w>': 112, 't o o </w>': 61, 'm u c h </w>': 75, 's t r u g g l i n g </w>': 2, 'b r a i n </w>': 6, 'm e n t i o n </w>': 9, 't h i s </w>': 307, 'o n e </w>': 85, 'd o e s n </w>': 9, 't </w>': 136, 'f a k e </w>': 6, 'i m </w>': 405, 'm o r e </w>': 124, 's c a r e d </w>': 12, 'l i k e </w>': 463, 'd r a m a s </w>': 1, 'o r </w>': 188, 't h r i l l e r s </w>': 1, 'a r e </w>': 132, 'a c t u a l l y </w>': 30, 'c a p a b l e </w>': 3, 'h a p p e n i n g </w>': 5, 'l e a v e </w>': 14, 'd i s t u r b e d </w>': 8, 'g r o g g y </w>': 8, 's u p e r </w>': 5, 't i r e d </w>': 9, 'd u r i n g </w>': 10, 'm o s t </w>': 39, 'f a l l </w>': 6, 'w e </w>': 83, 'e n d e d </w>': 4, 'u p </w>': 139, 's t a y i n g </w>': 4, 'h o m e </w>': 31, 't h a n k s g i v i n g </w>': 2, 'i n s t e a d </w>': 12, 'm a k i n g </w>': 22, 'h o u r </w>': 7, 't r i p </w>': 4, 'j i m m y s </w>': 1, 'f a m i l y </w>': 37, 'a w k w a r d </w>': 7, 'h a v e n t </w>': 16, 'b e e n </w>': 114, 'l a t e l y </w>': 21, 'a m </w>': 310, 's e r i o u s l y </w>': 6, 'd e p r e s s e d </w>': 11, 'i s </w>': 330, 'u n f o r t u n a t e </w>': 4, 'h a d </w>': 98, 't a k e </w>': 31, 't h e s e </w>': 69, 'd r a s t i c  ...

# %% [markdown]
# Generate all possible tokens from the vocabulary

# %%
tokens = set(tokenizer.tokens)
# write tokens to tokens.txt
with open('tokens.txt', 'w') as f:
    for token in tokens:
        # replace </w> with $
        token = token.replace('</w>', '$')
        f.write(token + '\n')

# %% [markdown]
# Generate all merge rules learnt after learning the vocabulary

# %%
with open('merges.txt', 'w') as f:
    for merge, freq in tokenizer.merges.items():
        # replace </w> with $ 
        merge = list(merge)
        merge[0] = merge[0].replace('</w>', '$')
        merge[1] = merge[1].replace('</w>', '$')
        f.write(merge[0] + ',' + merge[1] + '\n')

# %%
sample_corpus = []
with open('sample_corpus.txt', 'r') as f:
    for line in f:
        sample_corpus.append(line.strip())

for sentence in sample_corpus:
    # print("sentence: ", sentence)
    with open('tokenized_samples.txt', 'a') as f:
        f.write(tokenizer.tokenize(sentence) + '\n')
# Out:
# sentence:  ['g', 'r', 'e', 'e', 'n', '</w>', 'g', 'r', 'e', 'e', 'd', '</w>']
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d_,_</w>_
# merge_rules:  ('e', '</w>')
# rule1: _e_,_</w>_ , rule2:  _e</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d_,_</w>_
# merge_rules:  ('t', '</w>')
# rule1: _t_,_</w>_ , rule2:  _t</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d_,_</w>_
# merge_rules:  ('d', '</w>')
# rule1: _d_,_</w>_ , rule2:  _d</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('t', 'h')
# rule1: _t_,_h_ , rule2:  _th_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('i', 'n')
# rule1: _i_,_n_ , rule2:  _in_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('s', '</w>')
# rule1: _s_,_</w>_ , rule2:  _s</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('i', '</w>')
# rule1: _i_,_</w>_ , rule2:  _i</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('e', 'l')
# rule1: _e_,_l_ , rule2:  _el_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('y', '</w>')
# rule1: _y_,_</w>_ , rule2:  _y</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('a', 'n')
# rule1: _a_,_n_ , rule2:  _an_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('f', 'e')
# rule1: _f_,_e_ , rule2:  _fe_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('in', 'g')
# rule1: _in_,_g_ , rule2:  _ing_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('fe', 'el')
# rule1: _fe_,_el_ , rule2:  _feel_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('ing', '</w>')
# rule1: _ing_,_</w>_ , rule2:  _ing</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('o', '</w>')
# rule1: _o_,_</w>_ , rule2:  _o</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('e', 'r')
# rule1: _e_,_r_ , rule2:  _er_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('o', 'u')
# rule1: _o_,_u_ , rule2:  _ou_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_e_,_d</w>_
# merge_rules:  ('e', 'd</w>')
# rule1: _e_,_d</w>_ , rule2:  _ed</w>_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('o', 'n')
# rule1: _o_,_n_ , rule2:  _on_
# sentence:  _g_,_r_,_e_,_e_,_n_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('e', 'n')
# rule1: _e_,_n_ , rule2:  _en_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('feel', '</w>')
# rule1: _feel_,_</w>_ , rule2:  _feel</w>_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('an', 'd</w>')
# rule1: _an_,_d</w>_ , rule2:  _and</w>_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('o', 'r')
# rule1: _o_,_r_ , rule2:  _or_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('t', 'o</w>')
# rule1: _t_,_o</w>_ , rule2:  _to</w>_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('a', 'l')
# rule1: _a_,_l_ , rule2:  _al_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('th', 'e</w>')
# rule1: _th_,_e</w>_ , rule2:  _the</w>_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('m', '</w>')
# rule1: _m_,_</w>_ , rule2:  _m</w>_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('a', 't</w>')
# rule1: _a_,_t</w>_ , rule2:  _at</w>_
# sentence:  _g_,_r_,_e_,_en_,_</w>_,_g_,_r_,_e_,_ed</w>_
# merge_rules:  ('r', 'e')
# rule1: _r_,_e_ , rule2:  _re_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', '</w>')
# rule1: _f_,_</w>_ , rule2:  _f</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'r')
# rule1: _a_,_r_ , rule2:  _ar_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', '</w>')
# rule1: _a_,_</w>_ , rule2:  _a</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'i')
# rule1: _t_,_i_ , rule2:  _ti_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'i')
# rule1: _l_,_i_ , rule2:  _li_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('er', '</w>')
# rule1: _er_,_</w>_ , rule2:  _er</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', '</w>')
# rule1: _l_,_</w>_ , rule2:  _l</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'at</w>')
# rule1: _th_,_at</w>_ , rule2:  _that</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('feel', 'ing</w>')
# rule1: _feel_,_ing</w>_ , rule2:  _feeling</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 't')
# rule1: _s_,_t_ , rule2:  _st_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'a')
# rule1: _h_,_a_ , rule2:  _ha_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'e</w>')
# rule1: _m_,_e</w>_ , rule2:  _me</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'f</w>')
# rule1: _o_,_f</w>_ , rule2:  _of</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'y</w>')
# rule1: _l_,_y</w>_ , rule2:  _ly</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'h')
# rule1: _w_,_h_ , rule2:  _wh_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('v', 'e</w>')
# rule1: _v_,_e</w>_ , rule2:  _ve</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('in', '</w>')
# rule1: _in_,_</w>_ , rule2:  _in</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 's</w>')
# rule1: _i_,_s</w>_ , rule2:  _is</w>_
# sentence:  _g_,_re_,_en_,_</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('en', '</w>')
# rule1: _en_,_</w>_ , rule2:  _en</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('u', 's')
# rule1: _u_,_s_ , rule2:  _us_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 't</w>')
# rule1: _i_,_t</w>_ , rule2:  _it</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'y</w>')
# rule1: _m_,_y</w>_ , rule2:  _my</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('or', '</w>')
# rule1: _or_,_</w>_ , rule2:  _or</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'w')
# rule1: _o_,_w_ , rule2:  _ow_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('k', 'e</w>')
# rule1: _k_,_e</w>_ , rule2:  _ke</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('on', '</w>')
# rule1: _on_,_</w>_ , rule2:  _on</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'a')
# rule1: _w_,_a_ , rule2:  _wa_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'e')
# rule1: _b_,_e_ , rule2:  _be_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 't')
# rule1: _a_,_t_ , rule2:  _at_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'h')
# rule1: _c_,_h_ , rule2:  _ch_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'e</w>')
# rule1: _l_,_e</w>_ , rule2:  _le</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('r', 'i')
# rule1: _r_,_i_ , rule2:  _ri_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 's</w>')
# rule1: _e_,_s</w>_ , rule2:  _es</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'i')
# rule1: _w_,_i_ , rule2:  _wi_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'b')
# rule1: _a_,_b_ , rule2:  _ab_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 'm</w>')
# rule1: _i_,_m</w>_ , rule2:  _im</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'm')
# rule1: _o_,_m_ , rule2:  _om_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('k', '</w>')
# rule1: _k_,_</w>_ , rule2:  _k</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('li', 'ke</w>')
# rule1: _li_,_ke</w>_ , rule2:  _like</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 's')
# rule1: _e_,_s_ , rule2:  _es_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ou', 't</w>')
# rule1: _ou_,_t</w>_ , rule2:  _out</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'h')
# rule1: _g_,_h_ , rule2:  _gh_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'h')
# rule1: _s_,_h_ , rule2:  _sh_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'o')
# rule1: _l_,_o_ , rule2:  _lo_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 't')
# rule1: _i_,_t_ , rule2:  _it_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'o</w>')
# rule1: _s_,_o</w>_ , rule2:  _so</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ow', '</w>')
# rule1: _ow_,_</w>_ , rule2:  _ow</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'u')
# rule1: _b_,_u_ , rule2:  _bu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'c')
# rule1: _a_,_c_ , rule2:  _ac_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'u')
# rule1: _s_,_u_ , rule2:  _su_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', '</w>')
# rule1: _p_,_</w>_ , rule2:  _p</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'i')
# rule1: _d_,_i_ , rule2:  _di_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', '</w>')
# rule1: _th_,_</w>_ , rule2:  _th</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'or</w>')
# rule1: _f_,_or</w>_ , rule2:  _for</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'a')
# rule1: _m_,_a_ , rule2:  _ma_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('an', '</w>')
# rule1: _an_,_</w>_ , rule2:  _an</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('n', 'o')
# rule1: _n_,_o_ , rule2:  _no_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 's')
# rule1: _a_,_s_ , rule2:  _as_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('u', 'n')
# rule1: _u_,_n_ , rule2:  _un_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('bu', 't</w>')
# rule1: _bu_,_t</w>_ , rule2:  _but</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 't')
# rule1: _t_,_t_ , rule2:  _tt_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wa', 's</w>')
# rule1: _wa_,_s</w>_ , rule2:  _was</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('v', 'er')
# rule1: _v_,_er_ , rule2:  _ver_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'm</w>')
# rule1: _a_,_m</w>_ , rule2:  _am</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'd</w>')
# rule1: _l_,_d</w>_ , rule2:  _ld</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('r', 'o')
# rule1: _r_,_o_ , rule2:  _ro_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('y', 'ou')
# rule1: _y_,_ou_ , rule2:  _you_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('al', 'ly</w>')
# rule1: _al_,_ly</w>_ , rule2:  _ally</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'e')
# rule1: _th_,_e_ , rule2:  _the_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'e')
# rule1: _l_,_e_ , rule2:  _le_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wi', 'th</w>')
# rule1: _wi_,_th</w>_ , rule2:  _with</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'is</w>')
# rule1: _th_,_is</w>_ , rule2:  _this</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'e</w>')
# rule1: _b_,_e</w>_ , rule2:  _be</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ha', 've</w>')
# rule1: _ha_,_ve</w>_ , rule2:  _have</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ab', 'out</w>')
# rule1: _ab_,_out</w>_ , rule2:  _about</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 'r')
# rule1: _i_,_r_ , rule2:  _ir_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('no', 't</w>')
# rule1: _no_,_t</w>_ , rule2:  _not</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'l</w>')
# rule1: _l_,_l</w>_ , rule2:  _ll</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'i')
# rule1: _s_,_i_ , rule2:  _si_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'a')
# rule1: _c_,_a_ , rule2:  _ca_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ch', '</w>')
# rule1: _ch_,_</w>_ , rule2:  _ch</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 's</w>')
# rule1: _a_,_s</w>_ , rule2:  _as</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('us', 't</w>')
# rule1: _us_,_t</w>_ , rule2:  _ust</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('n', 'e')
# rule1: _n_,_e_ , rule2:  _ne_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'p')
# rule1: _p_,_p_ , rule2:  _pp_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'o')
# rule1: _g_,_o_ , rule2:  _go_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('r', 'a')
# rule1: _r_,_a_ , rule2:  _ra_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'e')
# rule1: _p_,_e_ , rule2:  _pe_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'a')
# rule1: _d_,_a_ , rule2:  _da_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('n', 'ow</w>')
# rule1: _n_,_ow</w>_ , rule2:  _now</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('an', 't</w>')
# rule1: _an_,_t</w>_ , rule2:  _ant</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ou', 'ld</w>')
# rule1: _ou_,_ld</w>_ , rule2:  _ould</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('al', 'l</w>')
# rule1: _al_,_l</w>_ , rule2:  _all</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wh', 'en</w>')
# rule1: _wh_,_en</w>_ , rule2:  _when</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('j', 'ust</w>')
# rule1: _j_,_ust</w>_ , rule2:  _just</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('you', '</w>')
# rule1: _you_,_</w>_ , rule2:  _you</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'e')
# rule1: _s_,_e_ , rule2:  _se_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('al', '</w>')
# rule1: _al_,_</w>_ , rule2:  _al</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('on', 'e</w>')
# rule1: _on_,_e</w>_ , rule2:  _one</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'a')
# rule1: _s_,_a_ , rule2:  _sa_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('er', 'e</w>')
# rule1: _er_,_e</w>_ , rule2:  _ere</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 'c')
# rule1: _i_,_c_ , rule2:  _ic_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('us', 'e</w>')
# rule1: _us_,_e</w>_ , rule2:  _use</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'ed</w>')
# rule1: _s_,_ed</w>_ , rule2:  _sed</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'ed</w>')
# rule1: _t_,_ed</w>_ , rule2:  _ted</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 't</w>')
# rule1: _e_,_t</w>_ , rule2:  _et</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'p')
# rule1: _o_,_p_ , rule2:  _op_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'u')
# rule1: _f_,_u_ , rule2:  _fu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'on')
# rule1: _c_,_on_ , rule2:  _con_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('u', 'r')
# rule1: _u_,_r_ , rule2:  _ur_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ou', 's</w>')
# rule1: _ou_,_s</w>_ , rule2:  _ous</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('gh', 't</w>')
# rule1: _gh_,_t</w>_ , rule2:  _ght</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 'm')
# rule1: _e_,_m_ , rule2:  _em_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('en', 't</w>')
# rule1: _en_,_t</w>_ , rule2:  _ent</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ca', 'use</w>')
# rule1: _ca_,_use</w>_ , rule2:  _cause</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('re', 's')
# rule1: _re_,_s_ , rule2:  _res_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 'v')
# rule1: _e_,_v_ , rule2:  _ev_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('n', '</w>')
# rule1: _n_,_</w>_ , rule2:  _n</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'i')
# rule1: _m_,_i_ , rule2:  _mi_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'e')
# rule1: _w_,_e_ , rule2:  _we_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'e</w>')
# rule1: _s_,_e</w>_ , rule2:  _se</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('om', 'e')
# rule1: _om_,_e_ , rule2:  _ome_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'ing</w>')
# rule1: _th_,_ing</w>_ , rule2:  _thing</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'me</w>')
# rule1: _o_,_me</w>_ , rule2:  _ome</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'ome')
# rule1: _s_,_ome_ , rule2:  _some_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'el')
# rule1: _s_,_el_ , rule2:  _sel_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('be', 'cause</w>')
# rule1: _be_,_cause</w>_ , rule2:  _because</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 't</w>')
# rule1: _s_,_t</w>_ , rule2:  _st</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'o')
# rule1: _t_,_o_ , rule2:  _to_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'om')
# rule1: _c_,_om_ , rule2:  _com_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'd')
# rule1: _a_,_d_ , rule2:  _ad_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('or', 'e</w>')
# rule1: _or_,_e</w>_ , rule2:  _ore</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ar', 'e</w>')
# rule1: _ar_,_e</w>_ , rule2:  _are</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 'x')
# rule1: _e_,_x_ , rule2:  _ex_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'y</w>')
# rule1: _b_,_y</w>_ , rule2:  _by</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('es', 's</w>')
# rule1: _es_,_s</w>_ , rule2:  _ess</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ti', 'c')
# rule1: _ti_,_c_ , rule2:  _tic_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'g')
# rule1: _a_,_g_ , rule2:  _ag_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'o')
# rule1: _m_,_o_ , rule2:  _mo_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ti', 'on</w>')
# rule1: _ti_,_on</w>_ , rule2:  _tion</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 'ar')
# rule1: _e_,_ar_ , rule2:  _ear_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'or')
# rule1: _w_,_or_ , rule2:  _wor_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ver', 'y</w>')
# rule1: _ver_,_y</w>_ , rule2:  _very</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('re', 'ally</w>')
# rule1: _re_,_ally</w>_ , rule2:  _really</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 's</w>')
# rule1: _d_,_s</w>_ , rule2:  _ds</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'p')
# rule1: _m_,_p_ , rule2:  _mp_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('el', 'y</w>')
# rule1: _el_,_y</w>_ , rule2:  _ely</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'er</w>')
# rule1: _th_,_er</w>_ , rule2:  _ther</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('k', 'ing</w>')
# rule1: _k_,_ing</w>_ , rule2:  _king</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'e</w>')
# rule1: _c_,_e</w>_ , rule2:  _ce</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('sel', 'f</w>')
# rule1: _sel_,_f</w>_ , rule2:  _self</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'o</w>')
# rule1: _d_,_o</w>_ , rule2:  _do</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('gh', '</w>')
# rule1: _gh_,_</w>_ , rule2:  _gh</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('r', '</w>')
# rule1: _r_,_</w>_ , rule2:  _r</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 's</w>')
# rule1: _t_,_s</w>_ , rule2:  _ts</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('fu', 'l</w>')
# rule1: _fu_,_l</w>_ , rule2:  _ful</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('su', 'r')
# rule1: _su_,_r_ , rule2:  _sur_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ou', 'n')
# rule1: _ou_,_n_ , rule2:  _oun_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('u', 'p</w>')
# rule1: _u_,_p</w>_ , rule2:  _up</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('k', 'now</w>')
# rule1: _k_,_now</w>_ , rule2:  _know</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'o')
# rule1: _p_,_o_ , rule2:  _po_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('at', 'ed</w>')
# rule1: _at_,_ed</w>_ , rule2:  _ated</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'r')
# rule1: _t_,_r_ , rule2:  _tr_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', '</w>')
# rule1: _g_,_</w>_ , rule2:  _g</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'an</w>')
# rule1: _c_,_an</w>_ , rule2:  _can</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 've</w>')
# rule1: _i_,_ve</w>_ , rule2:  _ive</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'er')
# rule1: _p_,_er_ , rule2:  _per_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'e')
# rule1: _d_,_e_ , rule2:  _de_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 'f</w>')
# rule1: _i_,_f</w>_ , rule2:  _if</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wh', 'at</w>')
# rule1: _wh_,_at</w>_ , rule2:  _what</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ing', 's</w>')
# rule1: _ing_,_s</w>_ , rule2:  _ings</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'ore</w>')
# rule1: _m_,_ore</w>_ , rule2:  _more</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('at', 'e</w>')
# rule1: _at_,_e</w>_ , rule2:  _ate</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'a')
# rule1: _t_,_a_ , rule2:  _ta_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'er')
# rule1: _t_,_er_ , rule2:  _ter_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('da', 'y</w>')
# rule1: _da_,_y</w>_ , rule2:  _day</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ou', 'gh</w>')
# rule1: _ou_,_gh</w>_ , rule2:  _ough</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('q', 'u')
# rule1: _q_,_u_ , rule2:  _qu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wa', 'y</w>')
# rule1: _wa_,_y</w>_ , rule2:  _way</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('it', 's</w>')
# rule1: _it_,_s</w>_ , rule2:  _its</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('st', 'r')
# rule1: _st_,_r_ , rule2:  _str_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 'd</w>')
# rule1: _i_,_d</w>_ , rule2:  _id</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ti', 'me</w>')
# rule1: _ti_,_me</w>_ , rule2:  _time</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'o')
# rule1: _b_,_o_ , rule2:  _bo_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'y')
# rule1: _m_,_y_ , rule2:  _my_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'ow</w>')
# rule1: _h_,_ow</w>_ , rule2:  _how</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'ti')
# rule1: _s_,_ti_ , rule2:  _sti_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('y', 's</w>')
# rule1: _y_,_s</w>_ , rule2:  _ys</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('my', 'self</w>')
# rule1: _my_,_self</w>_ , rule2:  _myself</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('an', 'g')
# rule1: _an_,_g_ , rule2:  _ang_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'ro')
# rule1: _f_,_ro_ , rule2:  _fro_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('fro', 'm</w>')
# rule1: _fro_,_m</w>_ , rule2:  _from</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'i')
# rule1: _f_,_i_ , rule2:  _fi_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'l')
# rule1: _o_,_l_ , rule2:  _ol_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('tt', 'le</w>')
# rule1: _tt_,_le</w>_ , rule2:  _ttle</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('pe', 'op')
# rule1: _pe_,_op_ , rule2:  _peop_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('be', 'en</w>')
# rule1: _be_,_en</w>_ , rule2:  _been</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'e</w>')
# rule1: _d_,_e</w>_ , rule2:  _de</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'ing</w>')
# rule1: _t_,_ing</w>_ , rule2:  _ting</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ab', 'le</w>')
# rule1: _ab_,_le</w>_ , rule2:  _able</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('peop', 'le</w>')
# rule1: _peop_,_le</w>_ , rule2:  _people</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'l')
# rule1: _p_,_l_ , rule2:  _pl_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('li', 'ttle</w>')
# rule1: _li_,_ttle</w>_ , rule2:  _little</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', '</w>')
# rule1: _w_,_</w>_ , rule2:  _w</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'et</w>')
# rule1: _g_,_et</w>_ , rule2:  _get</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'in')
# rule1: _th_,_in_ , rule2:  _thin_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wi', 'll</w>')
# rule1: _wi_,_ll</w>_ , rule2:  _will</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('the', 'y</w>')
# rule1: _the_,_y</w>_ , rule2:  _they</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ti', 'on')
# rule1: _ti_,_on_ , rule2:  _tion_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'e</w>')
# rule1: _f_,_e</w>_ , rule2:  _fe</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('v', 'er</w>')
# rule1: _v_,_er</w>_ , rule2:  _ver</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'ant</w>')
# rule1: _w_,_ant</w>_ , rule2:  _want</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('the', 'm</w>')
# rule1: _the_,_m</w>_ , rule2:  _them</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'e</w>')
# rule1: _h_,_e</w>_ , rule2:  _he</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'o')
# rule1: _d_,_o_ , rule2:  _do_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('sti', 'll</w>')
# rule1: _sti_,_ll</w>_ , rule2:  _still</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'er</w>')
# rule1: _t_,_er</w>_ , rule2:  _ter</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'd</w>')
# rule1: _o_,_d</w>_ , rule2:  _od</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'i')
# rule1: _c_,_i_ , rule2:  _ci_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('v', 'i')
# rule1: _v_,_i_ , rule2:  _vi_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'd</w>')
# rule1: _a_,_d</w>_ , rule2:  _ad</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('er', 's</w>')
# rule1: _er_,_s</w>_ , rule2:  _ers</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('n', 't</w>')
# rule1: _n_,_t</w>_ , rule2:  _nt</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('k', 'ed</w>')
# rule1: _k_,_ed</w>_ , rule2:  _ked</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'ould</w>')
# rule1: _w_,_ould</w>_ , rule2:  _would</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'a')
# rule1: _f_,_a_ , rule2:  _fa_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'er</w>')
# rule1: _h_,_er</w>_ , rule2:  _her</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ha', 'd</w>')
# rule1: _ha_,_d</w>_ , rule2:  _had</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'ome</w>')
# rule1: _s_,_ome</w>_ , rule2:  _some</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('li', 'fe</w>')
# rule1: _li_,_fe</w>_ , rule2:  _life</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('v', 'ing</w>')
# rule1: _v_,_ing</w>_ , rule2:  _ving</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'or')
# rule1: _f_,_or_ , rule2:  _for_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('on', 't</w>')
# rule1: _on_,_t</w>_ , rule2:  _ont</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'ar')
# rule1: _p_,_ar_ , rule2:  _par_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'in')
# rule1: _f_,_in_ , rule2:  _fin_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wh', 'i')
# rule1: _wh_,_i_ , rule2:  _whi_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'f')
# rule1: _a_,_f_ , rule2:  _af_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'u')
# rule1: _c_,_u_ , rule2:  _cu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('tic', '</w>')
# rule1: _tic_,_</w>_ , rule2:  _tic</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'f')
# rule1: _o_,_f_ , rule2:  _of_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('oun', 'd</w>')
# rule1: _oun_,_d</w>_ , rule2:  _ound</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'u')
# rule1: _m_,_u_ , rule2:  _mu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('lo', 'o')
# rule1: _lo_,_o_ , rule2:  _loo_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('thin', 'k</w>')
# rule1: _thin_,_k</w>_ , rule2:  _think</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'r')
# rule1: _g_,_r_ , rule2:  _gr_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('st', 'ar')
# rule1: _st_,_ar_ , rule2:  _star_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('z', 'ed</w>')
# rule1: _z_,_ed</w>_ , rule2:  _zed</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('wh', 'o</w>')
# rule1: _wh_,_o</w>_ , rule2:  _who</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 'p')
# rule1: _e_,_p_ , rule2:  _ep_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'in</w>')
# rule1: _a_,_in</w>_ , rule2:  _ain</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('be', 'ing</w>')
# rule1: _be_,_ing</w>_ , rule2:  _being</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 're')
# rule1: _p_,_re_ , rule2:  _pre_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('f', 'ri')
# rule1: _f_,_ri_ , rule2:  _fri_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('some', 'thing</w>')
# rule1: _some_,_thing</w>_ , rule2:  _something</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('as', 't</w>')
# rule1: _as_,_t</w>_ , rule2:  _ast</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('y', 'ing</w>')
# rule1: _y_,_ing</w>_ , rule2:  _ying</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('w', 'e</w>')
# rule1: _w_,_e</w>_ , rule2:  _we</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('an', 'y</w>')
# rule1: _an_,_y</w>_ , rule2:  _any</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'im</w>')
# rule1: _h_,_im</w>_ , rule2:  _him</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('en', 'd</w>')
# rule1: _en_,_d</w>_ , rule2:  _end</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'ro')
# rule1: _p_,_ro_ , rule2:  _pro_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'e')
# rule1: _g_,_e_ , rule2:  _ge_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'ed</w>')
# rule1: _m_,_ed</w>_ , rule2:  _med</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 'mp')
# rule1: _i_,_mp_ , rule2:  _imp_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ti', 'm')
# rule1: _ti_,_m_ , rule2:  _tim_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'ver')
# rule1: _o_,_ver_ , rule2:  _over_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('s', 'p')
# rule1: _s_,_p_ , rule2:  _sp_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'it</w>')
# rule1: _b_,_it</w>_ , rule2:  _bit</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('an', 'y')
# rule1: _an_,_y_ , rule2:  _any_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('re', 'm')
# rule1: _re_,_m_ , rule2:  _rem_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'ere</w>')
# rule1: _th_,_ere</w>_ , rule2:  _there</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('go', 'ing</w>')
# rule1: _go_,_ing</w>_ , rule2:  _going</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ac', 'k</w>')
# rule1: _ac_,_k</w>_ , rule2:  _ack</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('a', 'ma')
# rule1: _a_,_ma_ , rule2:  _ama_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'y</w>')
# rule1: _t_,_y</w>_ , rule2:  _ty</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ev', 'en</w>')
# rule1: _ev_,_en</w>_ , rule2:  _even</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'e')
# rule1: _m_,_e_ , rule2:  _me_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'o')
# rule1: _h_,_o_ , rule2:  _ho_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'ould</w>')
# rule1: _c_,_ould</w>_ , rule2:  _could</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ow', 'n</w>')
# rule1: _ow_,_n</w>_ , rule2:  _own</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('mu', 'ch</w>')
# rule1: _mu_,_ch</w>_ , rule2:  _much</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('v', 'ed</w>')
# rule1: _v_,_ed</w>_ , rule2:  _ved</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('l', 'ess</w>')
# rule1: _l_,_ess</w>_ , rule2:  _less</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('u', 'l')
# rule1: _u_,_l_ , rule2:  _ul_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ir', '</w>')
# rule1: _ir_,_</w>_ , rule2:  _ir</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('res', 'sed</w>')
# rule1: _res_,_sed</w>_ , rule2:  _ressed</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('n', 'o</w>')
# rule1: _n_,_o</w>_ , rule2:  _no</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 's')
# rule1: _i_,_s_ , rule2:  _is_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'el')
# rule1: _h_,_el_ , rule2:  _hel_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('su', 'pp')
# rule1: _su_,_pp_ , rule2:  _supp_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('sh', 'e</w>')
# rule1: _sh_,_e</w>_ , rule2:  _she</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ha', 'pp')
# rule1: _ha_,_pp_ , rule2:  _happ_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'nt</w>')
# rule1: _d_,_nt</w>_ , rule2:  _dnt</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('re', 'a')
# rule1: _re_,_a_ , rule2:  _rea_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('es', 'e</w>')
# rule1: _es_,_e</w>_ , rule2:  _ese</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'ly</w>')
# rule1: _t_,_ly</w>_ , rule2:  _tly</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('lo', 've</w>')
# rule1: _lo_,_ve</w>_ , rule2:  _love</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'ont</w>')
# rule1: _d_,_ont</w>_ , rule2:  _dont</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('sh', '</w>')
# rule1: _sh_,_</w>_ , rule2:  _sh</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ma', 'ke</w>')
# rule1: _ma_,_ke</w>_ , rule2:  _make</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('tim', 'es</w>')
# rule1: _tim_,_es</w>_ , rule2:  _times</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'ese</w>')
# rule1: _th_,_ese</w>_ , rule2:  _these</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('on', 'g</w>')
# rule1: _on_,_g</w>_ , rule2:  _ong</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'en')
# rule1: _t_,_en_ , rule2:  _ten_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('re', 'ad')
# rule1: _re_,_ad_ , rule2:  _read_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'ver</w>')
# rule1: _o_,_ver</w>_ , rule2:  _over</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('it', 'e</w>')
# rule1: _it_,_e</w>_ , rule2:  _ite</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'ings</w>')
# rule1: _th_,_ings</w>_ , rule2:  _things</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('di', 's')
# rule1: _di_,_s_ , rule2:  _dis_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('th', 'an</w>')
# rule1: _th_,_an</w>_ , rule2:  _than</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('p', 'ri')
# rule1: _p_,_ri_ , rule2:  _pri_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('on', 'ly</w>')
# rule1: _on_,_ly</w>_ , rule2:  _only</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'ther</w>')
# rule1: _o_,_ther</w>_ , rule2:  _other</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'l')
# rule1: _b_,_l_ , rule2:  _bl_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'ing</w>')
# rule1: _d_,_ing</w>_ , rule2:  _ding</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'ur')
# rule1: _t_,_ur_ , rule2:  _tur_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'is</w>')
# rule1: _h_,_is</w>_ , rule2:  _his</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'u')
# rule1: _g_,_u_ , rule2:  _gu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('tt', 'ing</w>')
# rule1: _tt_,_ing</w>_ , rule2:  _tting</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('al', 'so</w>')
# rule1: _al_,_so</w>_ , rule2:  _also</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'l')
# rule1: _c_,_l_ , rule2:  _cl_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('i', 'l')
# rule1: _i_,_l_ , rule2:  _il_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'e</w>')
# rule1: _t_,_e</w>_ , rule2:  _te</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'ear')
# rule1: _h_,_ear_ , rule2:  _hear_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'ar')
# rule1: _c_,_ar_ , rule2:  _car_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('go', 'od</w>')
# rule1: _go_,_od</w>_ , rule2:  _good</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'c')
# rule1: _o_,_c_ , rule2:  _oc_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'o</w>')
# rule1: _g_,_o</w>_ , rule2:  _go</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ac', 'e</w>')
# rule1: _ac_,_e</w>_ , rule2:  _ace</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ti', 've</w>')
# rule1: _ti_,_ve</w>_ , rule2:  _tive</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'ack</w>')
# rule1: _b_,_ack</w>_ , rule2:  _back</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('r', 'el')
# rule1: _r_,_el_ , rule2:  _rel_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 'en')
# rule1: _g_,_en_ , rule2:  _gen_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('y', 'ear')
# rule1: _y_,_ear_ , rule2:  _year_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('you', 'r</w>')
# rule1: _you_,_r</w>_ , rule2:  _your</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ev', 'er</w>')
# rule1: _ev_,_er</w>_ , rule2:  _ever</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'er</w>')
# rule1: _d_,_er</w>_ , rule2:  _der</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('b', 'el')
# rule1: _b_,_el_ , rule2:  _bel_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('to', 'o</w>')
# rule1: _to_,_o</w>_ , rule2:  _too</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('t', 'u')
# rule1: _t_,_u_ , rule2:  _tu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ou', 'r</w>')
# rule1: _ou_,_r</w>_ , rule2:  _our</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('r', 'e</w>')
# rule1: _r_,_e</w>_ , rule2:  _re</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('mo', 'st</w>')
# rule1: _mo_,_st</w>_ , rule2:  _most</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 'p</w>')
# rule1: _e_,_p</w>_ , rule2:  _ep</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('tt', 'y</w>')
# rule1: _tt_,_y</w>_ , rule2:  _tty</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('m', 'in')
# rule1: _m_,_in_ , rule2:  _min_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('k', 's</w>')
# rule1: _k_,_s</w>_ , rule2:  _ks</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ic', '</w>')
# rule1: _ic_,_</w>_ , rule2:  _ic</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('o', 'se</w>')
# rule1: _o_,_se</w>_ , rule2:  _ose</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'u')
# rule1: _d_,_u_ , rule2:  _du_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('st', 'u')
# rule1: _st_,_u_ , rule2:  _stu_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('d', 'on</w>')
# rule1: _d_,_on</w>_ , rule2:  _don</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('un', 'n')
# rule1: _un_,_n_ , rule2:  _unn_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'ou')
# rule1: _c_,_ou_ , rule2:  _cou_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ne', 'ed</w>')
# rule1: _ne_,_ed</w>_ , rule2:  _need</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('k', 'e')
# rule1: _k_,_e_ , rule2:  _ke_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('sur', 'e</w>')
# rule1: _sur_,_e</w>_ , rule2:  _sure</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'o')
# rule1: _c_,_o_ , rule2:  _co_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('com', 'p')
# rule1: _com_,_p_ , rule2:  _comp_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('whi', 'ch</w>')
# rule1: _whi_,_ch</w>_ , rule2:  _which</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('the', 'ir</w>')
# rule1: _the_,_ir</w>_ , rule2:  _their</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ar', 'd</w>')
# rule1: _ar_,_d</w>_ , rule2:  _ard</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('it', 'y</w>')
# rule1: _it_,_y</w>_ , rule2:  _ity</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('feel', 's</w>')
# rule1: _feel_,_s</w>_ , rule2:  _feels</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('e', 'ver')
# rule1: _e_,_ver_ , rule2:  _ever_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ir', 'd</w>')
# rule1: _ir_,_d</w>_ , rule2:  _ird</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('over', 'wh')
# rule1: _over_,_wh_ , rule2:  _overwh_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('overwh', 'el')
# rule1: _overwh_,_el_ , rule2:  _overwhel_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('overwhel', 'med</w>')
# rule1: _overwhel_,_med</w>_ , rule2:  _overwhelmed</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('c', 'ome</w>')
# rule1: _c_,_ome</w>_ , rule2:  _come</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ha', 's</w>')
# rule1: _ha_,_s</w>_ , rule2:  _has</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ever', 'y')
# rule1: _ever_,_y_ , rule2:  _every_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('supp', 'or')
# rule1: _supp_,_or_ , rule2:  _suppor_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('el', 'l</w>')
# rule1: _el_,_l</w>_ , rule2:  _ell</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('h', 'e')
# rule1: _h_,_e_ , rule2:  _he_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('us', 'ed</w>')
# rule1: _us_,_ed</w>_ , rule2:  _used</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('em', 'b')
# rule1: _em_,_b_ , rule2:  _emb_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('ar', 'ound</w>')
# rule1: _ar_,_ound</w>_ , rule2:  _around</w>_
# sentence:  _g_,_re_,_en</w>_,_g_,_re_,_ed</w>_
# merge_rules:  ('g', 're')
# rule1: _g_,_re_ , rule2:  _gre_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('ag', 'ain</w>')
# rule1: _ag_,_ain</w>_ , rule2:  _again</w>_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('d', 'ed</w>')
# rule1: _d_,_ed</w>_ , rule2:  _ded</w>_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('di', 'dnt</w>')
# rule1: _di_,_dnt</w>_ , rule2:  _didnt</w>_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('wa', 'ys</w>')
# rule1: _wa_,_ys</w>_ , rule2:  _ways</w>_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('f', 'el')
# rule1: _f_,_el_ , rule2:  _fel_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('sur', 'pri')
# rule1: _sur_,_pri_ , rule2:  _surpri_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('we', 'ird</w>')
# rule1: _we_,_ird</w>_ , rule2:  _weird</w>_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('on', 'g')
# rule1: _on_,_g_ , rule2:  _ong_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('a', 'm')
# rule1: _a_,_m_ , rule2:  _am_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('g', 'i')
# rule1: _g_,_i_ , rule2:  _gi_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('p', 'u')
# rule1: _p_,_u_ , rule2:  _pu_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('di', 'd</w>')
# rule1: _di_,_d</w>_ , rule2:  _did</w>_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('al', 'l')
# rule1: _al_,_l_ , rule2:  _all_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('ri', 'ght</w>')
# rule1: _ri_,_ght</w>_ , rule2:  _right</w>_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('j', 'o')
# rule1: _j_,_o_ , rule2:  _jo_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('a', 'u')
# rule1: _a_,_u_ , rule2:  _au_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('b', 'i')
# rule1: _b_,_i_ , rule2:  _bi_
# sentence:  _gre_,_en</w>_,_gre_,_ed</w>_
# merge_rules:  ('a', 'tion</w>')
# rule1: _a_,_tion</w>_ , rule2:  _ation</w>_
# ...
# merge_rules:  ('scho', 'ol</w>')
# rule1: _scho_,_ol</w>_ , rule2:  _school</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('f', 'r')
# rule1: _f_,_r_ , rule2:  _fr_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('po', 'int</w>')
# rule1: _po_,_int</w>_ , rule2:  _point</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('de', 'ci')
# rule1: _de_,_ci_ , rule2:  _deci_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('i', 'l</w>')
# rule1: _i_,_l</w>_ , rule2:  _il</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('every', 'one</w>')
# rule1: _every_,_one</w>_ , rule2:  _everyone</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('gr', 'ate')
# rule1: _gr_,_ate_ , rule2:  _grate_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('si', 'mp')
# rule1: _si_,_mp_ , rule2:  _simp_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ner', 'v')
# rule1: _ner_,_v_ , rule2:  _nerv_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('terri', 'fied</w>')
# rule1: _terri_,_fied</w>_ , rule2:  _terrified</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('rela', 'tion')
# rule1: _rela_,_tion_ , rule2:  _relation_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('w', 'ar')
# rule1: _w_,_ar_ , rule2:  _war_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ar', 'ly</w>')
# rule1: _ar_,_ly</w>_ , rule2:  _arly</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('lo', 'vely</w>')
# rule1: _lo_,_vely</w>_ , rule2:  _lovely</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('l', 'es</w>')
# rule1: _l_,_es</w>_ , rule2:  _les</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('suppor', 'tive</w>')
# rule1: _suppor_,_tive</w>_ , rule2:  _supportive</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ten', 'der</w>')
# rule1: _ten_,_der</w>_ , rule2:  _tender</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('en', 'c')
# rule1: _en_,_c_ , rule2:  _enc_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('wh', 'o')
# rule1: _wh_,_o_ , rule2:  _who_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('he', 'ad</w>')
# rule1: _he_,_ad</w>_ , rule2:  _head</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('w', 'ard</w>')
# rule1: _w_,_ard</w>_ , rule2:  _ward</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ous', 'ly</w>')
# rule1: _ous_,_ly</w>_ , rule2:  _ously</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('cont', 'inu')
# rule1: _cont_,_inu_ , rule2:  _continu_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('lon', 'ely</w>')
# rule1: _lon_,_ely</w>_ , rule2:  _lonely</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('sh', 'ed</w>')
# rule1: _sh_,_ed</w>_ , rule2:  _shed</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('di', 'dn</w>')
# rule1: _di_,_dn</w>_ , rule2:  _didn</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('h', 'ard</w>')
# rule1: _h_,_ard</w>_ , rule2:  _hard</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('su', 'b')
# rule1: _su_,_b_ , rule2:  _sub_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('en', 'tly</w>')
# rule1: _en_,_tly</w>_ , rule2:  _ently</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('p', 'ain</w>')
# rule1: _p_,_ain</w>_ , rule2:  _pain</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('tow', 'ards</w>')
# rule1: _tow_,_ards</w>_ , rule2:  _towards</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('el', 'se</w>')
# rule1: _el_,_se</w>_ , rule2:  _else</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('vi', 'e')
# rule1: _vi_,_e_ , rule2:  _vie_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('c', 'le')
# rule1: _c_,_le_ , rule2:  _cle_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ad', 'm')
# rule1: _ad_,_m_ , rule2:  _adm_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ma', 'd</w>')
# rule1: _ma_,_d</w>_ , rule2:  _mad</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('p', 'ast</w>')
# rule1: _p_,_ast</w>_ , rule2:  _past</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('reas', 'on</w>')
# rule1: _reas_,_on</w>_ , rule2:  _reason</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('bo', 'ok</w>')
# rule1: _bo_,_ok</w>_ , rule2:  _book</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('tur', 'e</w>')
# rule1: _tur_,_e</w>_ , rule2:  _ture</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('c', 'as')
# rule1: _c_,_as_ , rule2:  _cas_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('po', 'si')
# rule1: _po_,_si_ , rule2:  _posi_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('tic', 'ul')
# rule1: _tic_,_ul_ , rule2:  _ticul_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('hear', '</w>')
# rule1: _hear_,_</w>_ , rule2:  _hear</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('app', 're')
# rule1: _app_,_re_ , rule2:  _appre_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('th', 're')
# rule1: _th_,_re_ , rule2:  _thre_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('sympa', 'thetic</w>')
# rule1: _sympa_,_thetic</w>_ , rule2:  _sympathetic</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('o', 'id</w>')
# rule1: _o_,_id</w>_ , rule2:  _oid</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('anx', 'ious</w>')
# rule1: _anx_,_ious</w>_ , rule2:  _anxious</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('e', 'ach</w>')
# rule1: _e_,_ach</w>_ , rule2:  _each</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('impor', 'tant</w>')
# rule1: _impor_,_tant</w>_ , rule2:  _important</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('seem', 's</w>')
# rule1: _seem_,_s</w>_ , rule2:  _seems</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('re', 's</w>')
# rule1: _re_,_s</w>_ , rule2:  _res</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('pp', 'o')
# rule1: _pp_,_o_ , rule2:  _ppo_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('f', 'ru')
# rule1: _f_,_ru_ , rule2:  _fru_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('i', 'on</w>')
# rule1: _i_,_on</w>_ , rule2:  _ion</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('on', 'd</w>')
# rule1: _on_,_d</w>_ , rule2:  _ond</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('s', 'mi')
# rule1: _s_,_mi_ , rule2:  _smi_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('s', 'it</w>')
# rule1: _s_,_it</w>_ , rule2:  _sit</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ext', 'rem')
# rule1: _ext_,_rem_ , rule2:  _extrem_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('un', 'i')
# rule1: _un_,_i_ , rule2:  _uni_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('bel', 'ie')
# rule1: _bel_,_ie_ , rule2:  _belie_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('is', 'sed</w>')
# rule1: _is_,_sed</w>_ , rule2:  _issed</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('dis', 'c')
# rule1: _dis_,_c_ , rule2:  _disc_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('sor', 't</w>')
# rule1: _sor_,_t</w>_ , rule2:  _sort</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ou', 'l')
# rule1: _ou_,_l_ , rule2:  _oul_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('sh', 'o')
# rule1: _sh_,_o_ , rule2:  _sho_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('z', 'y</w>')
# rule1: _z_,_y</w>_ , rule2:  _zy</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('t', 'el')
# rule1: _t_,_el_ , rule2:  _tel_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('grate', 'ful</w>')
# rule1: _grate_,_ful</w>_ , rule2:  _grateful</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('under', 'stand</w>')
# rule1: _under_,_stand</w>_ , rule2:  _understand</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('w', 'ont</w>')
# rule1: _w_,_ont</w>_ , rule2:  _wont</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('nerv', 'ous</w>')
# rule1: _nerv_,_ous</w>_ , rule2:  _nervous</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('al', 's</w>')
# rule1: _al_,_s</w>_ , rule2:  _als</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('t', 're')
# rule1: _t_,_re_ , rule2:  _tre_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('us', 'u')
# rule1: _us_,_u_ , rule2:  _usu_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('stor', 'y</w>')
# rule1: _stor_,_y</w>_ , rule2:  _story</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ti', 'es</w>')
# rule1: _ti_,_es</w>_ , rule2:  _ties</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('thin', 'king</w>')
# rule1: _thin_,_king</w>_ , rule2:  _thinking</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('wi', 'sh</w>')
# rule1: _wi_,_sh</w>_ , rule2:  _wish</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('li', 'ked</w>')
# rule1: _li_,_ked</w>_ , rule2:  _liked</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('f', 'ound</w>')
# rule1: _f_,_ound</w>_ , rule2:  _found</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('m', 'an')
# rule1: _m_,_an_ , rule2:  _man_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('bo', 'o')
# rule1: _bo_,_o_ , rule2:  _boo_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('w', 'o')
# rule1: _w_,_o_ , rule2:  _wo_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ma', 'y')
# rule1: _ma_,_y_ , rule2:  _may_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('may', 'be</w>')
# rule1: _may_,_be</w>_ , rule2:  _maybe</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('t', 'ally</w>')
# rule1: _t_,_ally</w>_ , rule2:  _tally</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('h', 'ou')
# rule1: _h_,_ou_ , rule2:  _hou_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('fu', 'l')
# rule1: _fu_,_l_ , rule2:  _ful_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('b', 'ly</w>')
# rule1: _b_,_ly</w>_ , rule2:  _bly</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('fu', 'c')
# rule1: _fu_,_c_ , rule2:  _fuc_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('us', 'h')
# rule1: _us_,_h_ , rule2:  _ush_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('s', 'ol')
# rule1: _s_,_ol_ , rule2:  _sol_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ex', 'peri')
# rule1: _ex_,_peri_ , rule2:  _experi_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('th', 'y</w>')
# rule1: _th_,_y</w>_ , rule2:  _thy</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ki', 'ds</w>')
# rule1: _ki_,_ds</w>_ , rule2:  _kids</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('pers', 'on')
# rule1: _pers_,_on_ , rule2:  _person_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('do', 'es')
# rule1: _do_,_es_ , rule2:  _does_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('hav', 'ent</w>')
# rule1: _hav_,_ent</w>_ , rule2:  _havent</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('v', 'en</w>')
# rule1: _v_,_en</w>_ , rule2:  _ven</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('mor', 'ning</w>')
# rule1: _mor_,_ning</w>_ , rule2:  _morning</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('extrem', 'ely</w>')
# rule1: _extrem_,_ely</w>_ , rule2:  _extremely</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ta', 'king</w>')
# rule1: _ta_,_king</w>_ , rule2:  _taking</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('belie', 've</w>')
# rule1: _belie_,_ve</w>_ , rule2:  _believe</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('d', 'a</w>')
# rule1: _d_,_a</w>_ , rule2:  _da</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('mo', 'ther</w>')
# rule1: _mo_,_ther</w>_ , rule2:  _mother</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ar', 'ing</w>')
# rule1: _ar_,_ing</w>_ , rule2:  _aring</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('at', 'ure</w>')
# rule1: _at_,_ure</w>_ , rule2:  _ature</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('li', 'st')
# rule1: _li_,_st_ , rule2:  _list_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('st', 'an')
# rule1: _st_,_an_ , rule2:  _stan_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('s', 'l')
# rule1: _s_,_l_ , rule2:  _sl_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('bo', 'ther')
# rule1: _bo_,_ther_ , rule2:  _bother_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('d', 'ent</w>')
# rule1: _d_,_ent</w>_ , rule2:  _dent</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('rem', 'in')
# rule1: _rem_,_in_ , rule2:  _remin_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('star', 'ting</w>')
# rule1: _star_,_ting</w>_ , rule2:  _starting</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('v', 'en')
# rule1: _v_,_en_ , rule2:  _ven_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('lo', 'st</w>')
# rule1: _lo_,_st</w>_ , rule2:  _lost</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('w', 'ent</w>')
# rule1: _w_,_ent</w>_ , rule2:  _went</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('g', 's</w>')
# rule1: _g_,_s</w>_ , rule2:  _gs</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('par', 't</w>')
# rule1: _par_,_t</w>_ , rule2:  _part</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('lo', 'y')
# rule1: _lo_,_y_ , rule2:  _loy_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('th', 's</w>')
# rule1: _th_,_s</w>_ , rule2:  _ths</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('cl', 'u')
# rule1: _cl_,_u_ , rule2:  _clu_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('se', 't</w>')
# rule1: _se_,_t</w>_ , rule2:  _set</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('par', 'ticul')
# rule1: _par_,_ticul_ , rule2:  _particul_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('fre', 'e</w>')
# rule1: _fre_,_e</w>_ , rule2:  _free</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('c', 'en')
# rule1: _c_,_en_ , rule2:  _cen_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('del', 'ic')
# rule1: _del_,_ic_ , rule2:  _delic_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('gener', 'ous</w>')
# rule1: _gener_,_ous</w>_ , rule2:  _generous</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('d', 'ou')
# rule1: _d_,_ou_ , rule2:  _dou_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('comp', 'as')
# rule1: _comp_,_as_ , rule2:  _compas_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('ush', 'ed</w>')
# rule1: _ush_,_ed</w>_ , rule2:  _ushed</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('p', 'issed</w>')
# rule1: _p_,_issed</w>_ , rule2:  _pissed</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('un', 'sure</w>')
# rule1: _un_,_sure</w>_ , rule2:  _unsure</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('un', 'certain</w>')
# rule1: _un_,_certain</w>_ , rule2:  _uncertain</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('so', 'ci')
# rule1: _so_,_ci_ , rule2:  _soci_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('b', 'ro')
# rule1: _b_,_ro_ , rule2:  _bro_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('sto', 'p</w>')
# rule1: _sto_,_p</w>_ , rule2:  _stop</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('wat', 'ch')
# rule1: _wat_,_ch_ , rule2:  _watch_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('stu', 'ff</w>')
# rule1: _stu_,_ff</w>_ , rule2:  _stuff</w>_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
# merge_rules:  ('hel', 'pl')
# rule1: _hel_,_pl_ , rule2:  _helpl_
# sentence:  _pl_,_u_,_ck</w>_,_fu_,_ck</w>_
